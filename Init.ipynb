# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 94.9 MB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 63.2 MB/s eta 0:00:00
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 102.4 MB/s eta 0:00:00
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.1 MB/s eta 0:00:00
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 9.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 80.9 MB/s eta 0:00:00
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 33.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 150.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 1)) (24.1)
# Requirement already satisfied: numpy>=1.23 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 1)) (1.26.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.56.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 157.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp39-cp39-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 148.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from seaborn->-r ./requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: certifi>=2020.12.5 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from ucimlrepo->-r ./requirements.txt (line 3)) (2024.8.30)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 53.8 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 68.8 MB/s eta 0:00:00
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 73.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.25.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 MB 11.5 MB/s eta 0:00:00
# Collecting zipp>=3.1.0
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from pandas>=1.2->seaborn->-r ./requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: six>=1.5 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r ./requirements.txt (line 1)) (1.16.0)
# Installing collected packages: zipp, threadpoolctl, scipy, pyparsing, pillow, nvidia-nccl-cu12, kiwisolver, joblib, fonttools, cycler, contourpy, xgboost, scikit-learn, importlib-resources, ucimlrepo, matplotlib, imbalanced-learn, seaborn, mlxtend, imblearn
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.56.0 imbalanced-learn-0.12.4 imblearn-0.0 importlib-resources-6.5.2 joblib-1.4.2 kiwisolver-1.4.7 matplotlib-3.9.4 mlxtend-0.23.4 nvidia-nccl-cu12-2.25.1 pillow-11.1.0 pyparsing-3.2.1 scikit-learn-1.6.1 scipy-1.13.1 seaborn-0.13.2 threadpoolctl-3.5.0 ucimlrepo-0.0.7 xgboost-2.1.4 zipp-3.21.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=73c589da-27a4-44c1-8715-c36b04123c96' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
